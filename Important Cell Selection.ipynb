# %% [markdown]
# # Table of Contents
# 1. [Library Imports & Parameters](#cell-1-libraries)
# 2. [Data Import and Cleaning](#Data-import-and-cleaning)
# #### Ohm-wh vs Energy Density vs cell efficiency
# intent is to create a energy vs power density to have a general bounding box
# #### Absolute Cell tradeoff useable energy
# Intent is to show how this applies to cells we know of
# #### Heat Generation Bounding Box
# Shows what cells are applicable with different cooling
# #### Pack hypotheticals
# Shows how different counts fall within this graph
# #### Our pack
# Show the enepaq choices
# Show the parralel count
# Show the estimated non-cell DCIR
